# %%
import numpy as np
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import mean_squared_error
from tensorflow.keras.layers import Dropout, Flatten
from tensorflow.keras.layers import Activation, Flatten, Attention
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.layers import Input, Dense, LSTM, concatenate, dot, Dropout
from sklearn.metrics import mean_squared_error as mse

# %%
df=pd.read_csv('/content/train.csv')
df
# Out:
#                datetime  nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# 0      03-01-2015 01:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 1      03-01-2015 02:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2      03-01-2015 03:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 3      03-01-2015 04:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 4      03-01-2015 05:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                 ...         ...        ...       ...       ...        ...
# 43770  31-12-2019 19:00   1301.6065  26.635645  0.018421  0.013165  13.184052
# 43771  31-12-2019 20:00   1250.9634  26.495935  0.018162  0.014713  13.443892
# 43772  31-12-2019 21:00   1193.6802  26.354456  0.017980  0.013836  13.442195
# 43773  31-12-2019 22:00   1130.4575  26.166895  0.017965  0.018486  13.420656
# 43774  31-12-2019 23:00   1084.4737  25.976373  0.018072  0.023315  13.749788
#
#          T2M_san  QV2M_san   TQL_san    W2M_san    T2M_dav  QV2M_dav  \
# 0      23.482446  0.017272  0.001855  10.328949  22.662134  0.016562
# 1      23.399255  0.017265  0.001327  10.681517  22.578943  0.016509
# 2      23.343530  0.017211  0.001428  10.874924  22.531030  0.016479
# 3      23.238794  0.017128  0.002599  10.518620  22.512231  0.016487
# 4      23.075403  0.017059  0.001729   9.733589  22.481653  0.016456
# ...          ...       ...       ...        ...        ...       ...
# 43770  25.135645  0.018048  0.064240   3.086798  23.620020  0.016697
# 43771  24.769373  0.017781  0.058838   3.659980  23.284998  0.016606
# 43772  24.479456  0.017606  0.038086   3.769294  23.041956  0.016492
# 43773  24.112207  0.017393  0.020386   3.872397  22.862207  0.016401
# 43774  23.663873  0.017156  0.019531   4.165276  22.726373  0.016302
#
#         TQL_dav   W2M_dav  Holiday_ID  holiday  school
# 0      0.096100  5.364148           0        0       0
# 1      0.087646  5.572471           0        0       0
# 2      0.078735  5.871184           0        0       0
# 3      0.068390  5.883621           0        0       0
# 4      0.064362  5.611724           0        0       0
# ...         ...       ...         ...      ...     ...
# 43770  0.073425  3.865351          22        1       0
# 43771  0.064362  4.171572          22        1       0
# 43772  0.054260  4.045283          22        1       0
# 43773  0.055557  3.843736          22        1       0
# 43774  0.061371  3.793209          22        1       0
#
# [43775 rows x 17 columns]

# %%
df['datetime']=pd.to_datetime(df['datetime'])
df=df.set_index('datetime')

# %%
scaler = StandardScaler()
scaler = scaler.fit(df)
df_for_training_scaled = scaler.transform(df)
df_for_training_scaled
# Out:
# array([[-1.10462746, -0.91747214,  0.12897489, ..., -0.22523732,
#         -0.25820204, -1.68530387],
#        [-1.40522847, -0.89689509,  0.17742332, ..., -0.22523732,
#         -0.25820204, -1.68530387],
#        [-1.46675841, -0.87387983,  0.24959389, ..., -0.22523732,
#         -0.25820204, -1.68530387],
#        ...,
#        [ 0.04949601, -0.62137691, -0.24689001, ...,  6.55504517,
#          3.87293616, -1.68530387],
#        [-0.27721829, -0.73490163, -0.25623449, ...,  6.55504517,
#          3.87293616, -1.68530387],
#        [-0.51484757, -0.85021807, -0.18887726, ...,  6.55504517,
#          3.87293616, -1.68530387]])

# %%
def df_to_X_y2(df, window_size=6):
  X = []
  y = []
  for i in range(len(df)-window_size):
    row = [r for r in df[i:i+window_size]]
    X.append(row)
    label = df[i+window_size][0]
    y.append(label)
  return np.array(X), np.array(y)

# %%
X,y=df_to_X_y2(df_for_training_scaled)
split=int(len(df)*0.9)
X_train=X[:split]
y_train=y[:split]
X_test=X[split:]
y_test=y[split:]
X_train.shape, y_train.shape,X_test.shape, y_test.shape
# Out:
# ((39397, 6, 16), (39397,), (4372, 6, 16), (4372,))

# %%
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 6, 64)             20736
#
#  lstm_1 (LSTM)               (None, 6, 32)             12416
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 41,505
# Trainable params: 41,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1, verbose=1)
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
# Out:
# Epoch 1/100
# 1109/1109 [==============================] - 23s 16ms/step - loss: 0.1375 - val_loss: 0.0795
# Epoch 2/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0496 - val_loss: 0.0442
# Epoch 3/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0436 - val_loss: 0.0497
# Epoch 4/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0404 - val_loss: 0.0370
# Epoch 5/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0376 - val_loss: 0.0460
# Epoch 6/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0368 - val_loss: 0.0317
# Epoch 7/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0355 - val_loss: 0.0354
# Epoch 8/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0346 - val_loss: 0.0325
# Epoch 9/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0344 - val_loss: 0.0455
# Epoch 10/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0339 - val_loss: 0.0362
# Epoch 11/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0332 - val_loss: 0.0270
# Epoch 12/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0328 - val_loss: 0.0302
# Epoch 13/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0320 - val_loss: 0.0332
# Epoch 14/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0321 - val_loss: 0.0299
# Epoch 15/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0320 - val_loss: 0.0338
# Epoch 16/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0315 - val_loss: 0.0267
# Epoch 17/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0313 - val_loss: 0.0317
# Epoch 18/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0311 - val_loss: 0.0288
# Epoch 19/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0315 - val_loss: 0.0388
# Epoch 20/100
# 1109/1109 [==============================] - 16s 15ms/step - loss: 0.0307 - val_loss: 0.0264
# Epoch 21/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0300 - val_loss: 0.0302
# Epoch 22/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0307 - val_loss: 0.0365
# Epoch 23/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0294 - val_loss: 0.0337
# Epoch 24/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0295 - val_loss: 0.0261
# Epoch 25/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0298 - val_loss: 0.0270
# Epoch 26/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0290 - val_loss: 0.0244
# Epoch 27/100
# 1109/1109 [==============================] - 16s 15ms/step - loss: 0.0293 - val_loss: 0.0266
# Epoch 28/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0293 - val_loss: 0.0257
# Epoch 29/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0291 - val_loss: 0.0300
# Epoch 30/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0291 - val_loss: 0.0294
# Epoch 31/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0287 - val_loss: 0.0347
# Epoch 32/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0289 - val_loss: 0.0335
# Epoch 33/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0283 - val_loss: 0.0282
# Epoch 34/100
# 1109/1109 [==============================] - 16s 15ms/step - loss: 0.0280 - val_loss: 0.0361
# Epoch 35/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0277 - val_loss: 0.0307
# Epoch 36/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0276 - val_loss: 0.0303
# Epoch 37/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0272 - val_loss: 0.0305
# Epoch 38/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0273 - val_loss: 0.0297
# Epoch 39/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0271 - val_loss: 0.0302
# Epoch 40/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0273 - val_loss: 0.0336
# Epoch 41/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0274 - val_loss: 0.0278
# Epoch 42/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0274 - val_loss: 0.0297
# Epoch 43/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0271 - val_loss: 0.0314
# Epoch 44/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0271 - val_loss: 0.0325
# Epoch 45/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0262 - val_loss: 0.0305
# Epoch 46/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0274 - val_loss: 0.0344
# Epoch 47/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0275 - val_loss: 0.0384
# Epoch 48/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0263 - val_loss: 0.0320
# Epoch 49/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0264 - val_loss: 0.0337
# Epoch 50/100
# 1109/1109 [==============================] - 19s 17ms/step - loss: 0.0277 - val_loss: 0.0337
# Epoch 51/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0265 - val_loss: 0.0348
# Epoch 52/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0263 - val_loss: 0.0320
# Epoch 53/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0267 - val_loss: 0.0285
# Epoch 54/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0263 - val_loss: 0.0313
# Epoch 55/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0262 - val_loss: 0.0327
# Epoch 56/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0266 - val_loss: 0.0358
# Epoch 57/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0274 - val_loss: 0.0336
# Epoch 58/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0265 - val_loss: 0.0369
# Epoch 59/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0254 - val_loss: 0.0333
# Epoch 60/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0254 - val_loss: 0.0366
# Epoch 61/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0258 - val_loss: 0.0329
# Epoch 62/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0255 - val_loss: 0.0324
# Epoch 63/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0253 - val_loss: 0.0354
# Epoch 64/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0252 - val_loss: 0.0308
# Epoch 65/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0261 - val_loss: 0.0360
# Epoch 66/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0261 - val_loss: 0.0293
# Epoch 67/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0256 - val_loss: 0.0401
# Epoch 68/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0257 - val_loss: 0.0330
# Epoch 69/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0253 - val_loss: 0.0362
# Epoch 70/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0252 - val_loss: 0.0352
# Epoch 71/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0254 - val_loss: 0.0334
# Epoch 72/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0252 - val_loss: 0.0354
# Epoch 73/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0247 - val_loss: 0.0325
# Epoch 74/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0244 - val_loss: 0.0313
# Epoch 75/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0249 - val_loss: 0.0332
# Epoch 76/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0245 - val_loss: 0.0342
# Epoch 77/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0252 - val_loss: 0.0318
# Epoch 78/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0248 - val_loss: 0.0343
# Epoch 79/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0237 - val_loss: 0.0321
# Epoch 80/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0241 - val_loss: 0.0343
# Epoch 81/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0246 - val_loss: 0.0333
# Epoch 82/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0233 - val_loss: 0.0380
# Epoch 83/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0238 - val_loss: 0.0303
# Epoch 84/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0237 - val_loss: 0.0341
# Epoch 85/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0234 - val_loss: 0.0327
# Epoch 86/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0231 - val_loss: 0.0377
# Epoch 87/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0232 - val_loss: 0.0334
# Epoch 88/100
# 1109/1109 [==============================] - 17s 16ms/step - loss: 0.0236 - val_loss: 0.0312
# Epoch 89/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0244 - val_loss: 0.0379
# Epoch 90/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0239 - val_loss: 0.0354
# Epoch 91/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0227 - val_loss: 0.0430
# Epoch 92/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0231 - val_loss: 0.0366
# Epoch 93/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0223 - val_loss: 0.0344
# Epoch 94/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0230 - val_loss: 0.0311
# Epoch 95/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0233 - val_loss: 0.0341
# Epoch 96/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0243 - val_loss: 0.0372
# Epoch 97/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0229 - val_loss: 0.0319
# Epoch 98/100
# 1109/1109 [==============================] - 18s 16ms/step - loss: 0.0239 - val_loss: 0.0385
# Epoch 99/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0225 - val_loss: 0.0327
# Epoch 100/100
# 1109/1109 [==============================] - 17s 15ms/step - loss: 0.0230 - val_loss: 0.0336

# %%
def plot_predictions(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(y, predictions),np.sqrt(mse(y, predictions))

# %%
plot_predictions(model, X_test, y_test)
# Out:
# 137/137 [==============================] - 1s 5ms/step
# (      Predictions   Actuals
#  0        0.675721  0.747513
#  1        0.546344  0.592319
#  2        0.328995  0.250698
#  3       -0.095820 -0.055278
#  4       -0.336135 -0.410539
#  ...           ...       ...
#  4367     0.528544  0.607224
#  4368     0.368815  0.345517
#  4369     0.095729  0.049496
#  4370    -0.176482 -0.277218
#  4371    -0.500948 -0.514848
#
#  [4372 rows x 2 columns],
#  0.01955599264197473,
#  0.13984274254309637)

# %%
predictions = model.predict(X_test)
y_test=y_test.reshape(-1,1)
y_test.shape
# Out:
# 137/137 [==============================] - 1s 6ms/step
# (4372, 1)

# %%
d=df_for_training_scaled[-4372:,:]
Y_predicted = np.concatenate((predictions,d[-4372:,1:]), axis =1)
Y_tested = np.concatenate((y_test, d[-4372:,1:]), axis = 1)
Y_predicted = scaler.inverse_transform(Y_predicted)
Y_tested = scaler.inverse_transform(Y_tested)
Y_predicted = Y_predicted[:,0:1]
Y_tested = Y_tested[:,0:1]
print('Y_tested', Y_tested.shape)
print('Y_predicted', Y_predicted.shape)
# Out:
# Y_tested (4372, 1)
# Y_predicted (4372, 1)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error,mean_absolute_error
mse = mean_squared_error(Y_tested, Y_predicted)
mae=mean_absolute_error(Y_tested,Y_predicted)
mape=mean_absolute_percentage_error(Y_tested,Y_predicted)
rmse = np.sqrt(mse)
print('mean squared error: ',mse)
print('root mean squared error: ',rmse)
print('mean absolute error: ',mae)
print('mean absolute pourcentage error : ',mape)
# Out:
# mse:  732.3010802002394
# rmse:  27.061062067114797
# mae:  18.93695529414541
# mape:  0.015297173666032969

# %%
df2=pd.DataFrame(data={'Actuals': Y_tested.flatten(),'Predictions': Y_predicted.flatten()})
df2=df2.set_index(df[-4372:].index)
df2
# Out:
#                        Actuals  Predictions
# datetime
# 2019-02-07 20:00:00  1328.7539  1314.861494
# 2019-02-07 21:00:00  1298.7222  1289.825674
# 2019-02-07 22:00:00  1232.6149  1247.766211
# 2019-02-07 23:00:00  1173.4053  1165.559972
# 2019-03-07 00:00:00  1104.6586  1119.056436
# ...                        ...          ...
# 2019-12-31 19:00:00  1301.6065  1286.381178
# 2019-12-31 20:00:00  1250.9634  1255.471797
# 2019-12-31 21:00:00  1193.6802  1202.626695
# 2019-12-31 22:00:00  1130.4575  1149.951019
# 2019-12-31 23:00:00  1084.4737  1087.163435
#
# [4372 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))  
plt.plot(Y_predicted[:100,:], color= 'green',label = 'Predicted ')
plt.plot(Y_tested [:100,:], color = 'red',label = 'actuals')
plt.title('LSTM')
plt.legend()
plt.show()

# %%
plt.plot(df2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f237194a880>,
#  <matplotlib.lines.Line2D at 0x7f2371981d60>]
